# %%
import pandas as pd
import urllib.parse
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel
ds = pd.read_csv("search_24.csv")
tf = TfidfVectorizer(analyzer='word', ngram_range=(1, 20), min_df=0, stop_words='english')

term = ds['term'].astype(str).str.replace('+',' ',regex=True)
term = term.map(lambda x:urllib.parse.unquote(x))
term = term.apply(lambda x: x.strip('HTTP/1.1'))
user = ds['user_id']
user_term = pd.DataFrame(user)
user_term.insert(1,"term",term,True)
user_term.style.hide_index()
# print(user_term[:5].to_string(index=False))

tfidf_matrix = tf.fit_transform(user_term['term'])
cosine_similarities = linear_kernel(tfidf_matrix, tfidf_matrix)
results = {}

for idx, row in ds.iterrows():
    similar_indices = cosine_similarities[idx].argsort()[:-10:-1]
    similar_items = [(cosine_similarities[idx][i], user_term['user_id'][i]) for i in similar_indices]
    results[row['user_id']] = similar_items[1:]

def clean_list(list_item):
    if isinstance(list_item, list):
        for index in range(len(list_item)):
            if isinstance(list_item[index], list):
                list_item[index] = clean_list(list_item[index])
            if not isinstance(list_item[index], (int, tuple, float, list)):
                list_item[index] = list_item[index].strip()
    return list_item

def item(id):
    return clean_list(user_term.loc[user_term['user_id'] == id]['term'].tolist()[0])

def users_id(id):
    return clean_list(user_term.loc[user_term['user_id'] == id]['term'].to_string(index=False).split("\n"))

def recommend(id, num):
    recommend_list = []
    if (num == 0):
        print("Unable to recommend any search word as you have not chosen the number of search word to be recommended")
    elif (num==1):
        print("Recommending "+ id +", " + str(num) + " words similar to " + str(users_id(id)))
    else :
         print("Recommending "+ id +", " + str(num) + " words similar to " + str(users_id(id)))
    print("----------------------------------------------------------")
    recs = results[id][:num]
    for rec in recs:
            # print("You may also like to read: " + str(rec[1]) + " (score:" + str(rec[0]) + ")")
            if str(rec[0])!= '0.0'and str(rec[0])!='1.0':
                recommend_list.append(item(rec[1])+" "+ str(rec[0]))
   
    if set(recommend_list):
        for item_list in set(recommend_list):
            print(item_list)
        print()
    else:
        print("Please search more words to get recommendedation")
        print()

for id in set(user):
    recommend(id,10)
# Out:
# Recommending etsyben, 10 words similar to ['negative rates']
# ----------------------------------------------------------
# brexit fx gbpusd  0.2119756197342947
# arsley Energy / Jagged Peak Energy: Merger Agreement Continues Trend of Permian Consolidation and Negative Investor Response  0.048488539499497676
#
# Recommending dawsonge, 10 words similar to ['European Pharmaceuticals']
# ----------------------------------------------------------
# supply update  0.18931857613875905
# european high yield  0.13067195007220003
# european banks  0.20585480330169495
# asset managers  0.20585480330169495
# U.S. Airlines  0.34292346899211756
# european banks preview  0.13347141360410367
# european credit alpha  0.13637791756615064
#
# Recommending hsuben, 10 words similar to ['nickel']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending seideada, 10 words similar to ['aecom upgrade']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending 258113f3, 10 words similar to ['VW', 'Lamborgini']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending micielic, 10 words similar to ['SEK']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending c87d1856, 10 words similar to ['goog', 'goog']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending thommasa9, 10 words similar to ['ping']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending ganevae1, 10 words similar to ['wirecard']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending anjorinn, 10 words similar to ['paddy power', 'paddy power', 'paddy power', '888', 'betfair', 'betfred', 'betfair', 'paddy power', 'betfair', 'paddy power']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending lamgl, 10 words similar to ['West African Development Bank']
# ----------------------------------------------------------
# coop bank  0.1038172454876248
# danske bank  0.1038172454876248
# 01  0.11452210928388425
# bank  0.2308907349732252
#
# Recommending archardt, 10 words similar to ['eqa']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending collinev, 10 words similar to ['uruguay']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending rubinsoj, 10 words similar to ['troisi', 'troisi']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending aiskande, 10 words similar to ['rating suspended', 'trade war', 'trade war', 'realclearpolitics.com']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending ladavid2, 10 words similar to ['bond screening tool', 'bpl']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending nechaeva, 10 words similar to ['atos']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending pandanil, 10 words similar to ['European Medical Technology & Services: Perspe...', 'U.S. Health Care Services: Initiating Coverage...', '"Specialty Diagnostic"', 'Orthopedic', 'U.S. MEDICAL SUPPLIES & DEVICES: ORTHOPEDIC MA...', "U.S. Life Science Tools & Diagnostics: Jack's ..."]
# ----------------------------------------------------------
# 5/18/18 Thermo Fisher : Analyst Day Preview  0.02423568446656976
# phenomena across assets: bonds vs. equities of HY-rated  0.0335458845716568
# supply update  0.034095834908084585
# thoughts for the week ahead  0.03240007817035805
# bond screening tool  0.03167883683068608
#
# Recommending burgetom, 10 words similar to ['coop bank']
# ----------------------------------------------------------
# 01  0.22302103542283205
# bank  0.44963798785457443
# danske bank  0.20217432012191042
# global traders guide  0.20217432012191042
#
# Recommending alzatei2, 10 words similar to ['bank', 'copper model', 'copper']
# ----------------------------------------------------------
# bank  0.5372741880074929
# dr copper  0.5372741880074929
#
# Recommending kumar319, 10 words similar to ['bank', 'bank', 'bank', 'bank']
# ----------------------------------------------------------
# global traders guide  0.44963798785457443
# coop bank  0.44963798785457443
# 01  0.496001319832797
# danske bank  0.44963798785457443
#
# Recommending marshhar, 10 words similar to ['renishaw', 'renishaw', 'glaxo']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending renfr1, 10 words similar to ['china cpi', 'china cpi', 'RBA minutes']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending g09634069, 10 words similar to ['adient']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending zhangmen4, 10 words similar to ['eurocommercial']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending buttarka, 10 words similar to ['global traders guide', 'bank litigation', 'bank compliance']
# ----------------------------------------------------------
# 01  0.22302103542283205
# bank  0.44963798785457443
# danske bank  0.20217432012191042
# coop bank  0.20217432012191042
#
# Recommending schmidvo, 10 words similar to ['government bonds', 'ecb']
# ----------------------------------------------------------
# ecb qe  0.5424031076904392
#
# Recommending carrarma2, 10 words similar to ['danske bank']
# ----------------------------------------------------------
# 01  0.22302103542283205
# bank  0.44963798785457443
# coop bank  0.20217432012191042
# global traders guide  0.20217432012191042
#
# Recommending majidsha, 10 words similar to ['cspp']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending yupeter1, 10 words similar to ['gecina']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending nasdomin, 10 words similar to ['pet food']
# ----------------------------------------------------------
# European Food Retail  0.2033316019756188
# food places in Clinton  0.18721983889049593
# pet powerhouse  0.21660222240344232
# European Energy: UPDATE: European gas - a question of timing  0.12602412302642668
# pet powerhouse  0.3110716838381247
#
# Recommending ippolits, 10 words similar to ['treasury supply']
# ----------------------------------------------------------
# US Treasury Forecast  0.3057175780060899
# supply update  0.3206835088680556
# supply update  0.2897275912396612
# US Treasury Forecast  0.21332623507055035
# supply  0.5534110325007742
#
# Recommending florigst, 10 words similar to ['emmanuel cau']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending osborngr, 10 words similar to ['OFS 2020', 'seismic', 'siesmic utilisation', 'seismic', 'maire tecnimont', 'valuation green stocks', 'dogger veering north', 'wind', 'wind opportunities']
# ----------------------------------------------------------
# wind equipment  0.2798620464787006
# OFS 2020  0.5235305662961388
# wind equipment  0.5235305662961388
#
# Recommending fabiusna1, 10 words similar to ['ecuador', 'ecuador']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending frenchbe, 10 words similar to ['ESG']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending chansimi2, 10 words similar to ['prosus']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending eujinte, 10 words similar to ['raimo trend', 'raimo']
# ----------------------------------------------------------
# raimo trend  0.5655162400029825
#
# Recommending khanabba, 10 words similar to ['ludovico sapio', 'global outlook']
# ----------------------------------------------------------
# global outlook uncertainty  0.6191717190124756
# global economy  0.23477824430546562
# "GLOBAL 2019 e&P sPENDING oUTLOOK"  0.26399934921041884
# "GLOBAL 2019 e&P sPENDING oUTLOOK"  0.26786296207554927
# Chile Quarterly Outlook  0.17922771617568392
# ludovico sapio  0.9999999999999998
# usmca  0.18473519291699034
#
# Recommending parkde, 10 words similar to ['phenomena across assets: bonds vs. equities of...', 'phenomena across assets: bonds', 'phenomena of high', 'phenomena across assets', 'low vol. phen']
# ----------------------------------------------------------
# European Medical Technology & Services: Perspectives from the Middle East  0.0335458845716568
#
# Recommending h01916703, 10 words similar to ['uk contractors', 'uk contractors', 'construction']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending babirech, 10 words similar to ['Callum elliot', 'Callum elliot', 'Callum elliot']
# ----------------------------------------------------------
# Callum elliot  1.0000000000000002
#
# Recommending susilaan, 10 words similar to ['MBS', 'MBS', 'queen speech', 'fomc', 'fed']
# ----------------------------------------------------------
# Fed watch  0.5372741880074929
#
# Recommending shafqatk, 10 words similar to ['hsbc']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending stathoge, 10 words similar to ['hellenic petroleum', 'nmc']
# ----------------------------------------------------------
# NMC Health PLC: A clean beat in H1, new buyback & reports of bidders for NMC stake  0.21230569022833704
#
# Recommending widyokan, 10 words similar to ['bank holiday']
# ----------------------------------------------------------
# 01  0.22302103542283205
# bank  0.44963798785457443
# danske bank  0.20217432012191042
# coop bank  0.20217432012191042
#
# Recommending ryanesti, 10 words similar to ['Media']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending bajwaawa, 10 words similar to ['5g', '5g']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending petijean1, 10 words similar to ['yandex', 'indika', 'yandex']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending bartlea4, 10 words similar to ['LCS September 2019', 'LCS']
# ----------------------------------------------------------
# LCS September 2019  0.41294238988372384
#
# Recommending arunab, 10 words similar to ['trading account', 'trading account']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending arumugna, 10 words similar to ['what is priced in?']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending vijvarun, 10 words similar to ['European Credit Overview: Sound of silence']
# ----------------------------------------------------------
# asset managers  0.08435118107240007
# european credit alpha  0.23461185484504576
# IG Credit  0.08609460439050384
# european banks  0.08435118107240007
# US credit alpha  0.09384651315840753
# supply update  0.09384651315840753
# daily credit  0.09185928519738254
#
# Recommending seizandr, 10 words similar to ['Zambia']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending samalnil, 10 words similar to ['em flows', 'em flows']
# ----------------------------------------------------------
# ashish  0.30658116867447477
# EEMEA Instant Insights - Turkey (EM Macro & Sovereigns)  0.09077522029694683
# em flows  0.9999999999999998
#
# Recommending matsiaan, 10 words similar to ['catchment area discounter', 'lidl aldi', 'discounters london new stores aldi', 'discounters london mapping', 'discounters london', 'aldi mapping', 'mapping']
# ----------------------------------------------------------
# catchment area discounter  0.3985836825361798
# catchment area discounter  0.5562323476055683
#
# Recommending licharl5, 10 words similar to ['priya', 'harry mateer', 'harry mateer']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending gustavfr, 10 words similar to ['pegasus']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending chettyde, 10 words similar to ['stan solomon']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending pereiseo, 10 words similar to ['NMC Health PLC: A clean beat in H1, new buybac...']
# ----------------------------------------------------------
# halma plc  0.055668840303494956
# qiagen  0.057085221153409256
# hellenic petroleum 0.21230569022833704
# U.S. Airlines  0.022814334800690585
# C STAKE  0.10615284511416852
# catchment area discounter  0.02672953761450514
#
# Recommending kernemil, 10 words similar to ['airbus', 'airbus', 'milene kerner', 'milene kerner', 'airbus']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending saldanca, 10 words similar to ['latam', 'ecuador', 'canacol']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending maldomic, 10 words similar to ['thoughts for the week ahead', 'thoughts for the week ahead', 'thoughts for week ahead', 'thoughts for week ahead']
# ----------------------------------------------------------
# week ahead  0.6716289952662275
# European Energy: UPDATE: European gas - a question of timing  0.04037864397105655
# asia week ahead  0.4283227217474008
# houghts for the Week Ahead: Breaking the impasse, maybe  0.20377654656999844
#
# Recommending kamatram, 10 words similar to ['arsley Energy / Jagged Peak Energy: Merger Agr...', 'U.S. MLPs/U.S. Diversified Natural Gas: 3Q19 P...']
# ----------------------------------------------------------
# Q19 preview  0.08451604556475462
# U.S. MLPs  0.20900318971979442
# european banks preview  0.06434374428844213
# Singapore: MAS policy preview – Contrarian becomes consensus  0.034577563199531015
# question time  0.07846807198157041
# European Energy: UPDATE: European gas - a question of timing  0.03517020537124466
#
# Recommending felicmar, 10 words similar to ['albertsons', 'centurylink', 'century link']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending zhanlina, 10 words similar to ['rimas', 'rimas']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending vanesphi, 10 words similar to ['Euro Agg ex Corp 1-10 Yrs Aa']
# ----------------------------------------------------------
# 5/18/18 Thermo Fisher : Analyst Day Preview  0.050205082900702136
# IG OTR 10 YR  0.049516583636948656
# euro high yield corporate update  0.047850496182830674
#
# Recommending williasa13, 10 words similar to ['matalan']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending degennan, 10 words similar to ['U.S. MLPs', 'MLP']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending pateheen1, 10 words similar to ['Datadog']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending wepenera, 10 words similar to ['Ruyi']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending garcigil, 10 words similar to ['cielo', 'cielo']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending mahespri, 10 words similar to ['energy and pipelines: eneregy credit catal(i)st', 'energy and pipelines: eneregy credit cata', 'energy and pipelines: eneregy credit cata', 'energy and pipelines', 'energy and pipelines']
# ----------------------------------------------------------
# LNG Energy conference  0.17514260933257256
# energy and pipelines: eneregy credit catal(i)st  0.32274544769163754
# energy and pipelines: eneregy credit catal(i)st  0.9999999999999998
# energy and pipelines: eneregy credit catal(i)st  0.4032100427438813
# LNG Energy conference  0.16848456540064874
# LNG Energy conference  0.16738866315364812
#
# Recommending pedrazpi, 10 words similar to ['India: Growth: Flooded with bad news,']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending pesikanb, 10 words similar to ['Delticom', 'Delticom', 'Delticom']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending treendav, 10 words similar to ['uber']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending taylowil, 10 words similar to ['columbia']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending wellesas, 10 words similar to ['Credible Labs', 'Credible Labs', 'blane', 'Richard plepler', 'Richard plepler', 'plepler']
# ----------------------------------------------------------
# Credible Labs  0.560173460893011
# Recommending bignolib, 10 words similar to ['lebanon']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending wusiyao, 10 words similar to ['berkeley']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending bossueti, 10 words similar to ['ECB']
# ----------------------------------------------------------
# ecb qe  0.5424031076904392
#
# Recommending parlepra, 10 words similar to ['nvidia']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending casperts, 10 words similar to ['ross smotrich', 'ross smotrich']
# ----------------------------------------------------------
# smotrich  0.560173460893011
# ross smotrich  0.9999999999999998
#
# Recommending morossja, 10 words similar to ['datadog', 'datadog']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending merktsve, 10 words similar to ['renishaw', 'NORDEA COST OVERRUN']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending chenstev9, 10 words similar to ['UK']
# ----------------------------------------------------------
# uk contractors  0.5076367347422112
# uk property  0.3386889183569871
# uk property  0.48529899464450255
# uk jobs report  0.33122335287494176
#
# Recommending 70e4f358, 10 words similar to ['thales']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending kelserle, 10 words similar to ['L', 'GLPI', 'JNJ']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending pisacaed, 10 words similar to ['charts']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending bennetme4, 10 words similar to ['shale initiation', 'shale primer', 'plastics credit']
# ----------------------------------------------------------
# supply update  0.2208691705929248
# european credit alpha  0.15037679614031155
# Addressing the potential pitfalls of cds  0.1979981389574169
# IG Credit  0.2026249375100303
# daily credit  0.21619219990153862
# US credit alpha  0.2208691705929248
# STATISTICS  0.13705925050999454
#
# Recommending h05936152, 10 words similar to ['uk jobs report']
# ----------------------------------------------------------
# UK  0.33122335287494176
# uk property  0.11218167911978869
# uk property  0.16074236015299054
# uk contractors  0.16814114132380262
#
# Recommending yanghuas, 10 words similar to ['trade traiff']
# ----------------------------------------------------------
# hope trade  0.2717463022287522
# rating suspended  0.27374975893668246
# trade  0.5119888180316353
#
# Recommending kellyjos, 10 words similar to ['lbo targets', 'lbo targets']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending ungamand, 10 words similar to ['Conference Call: North America Financial Servi...', 'Energy roundtable dinner']
# ----------------------------------------------------------
# LNG Energy conference  0.07301659253011969
# LNG Energy conference  0.09861733230099244
# energy and pipelines: eneregy credit catal(i)st  0.14914049523398817
# LNG Energy conference  0.07389876431830589
# LNG Energy conference  0.10318558365424628
# LNG Energy conference  0.09926298508312059
#
# Recommending rohrahit, 10 words similar to ['cash settled swaptions']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending bouleyma, 10 words similar to ['nan', 'US Focus']
# ----------------------------------------------------------
# Korea Focus  0.5734027849349115
#
# Recommending wakudesu, 10 words similar to ['"Human Resource Management"', '"Human Resource Management"', 'uman Resource Management', 'uman Resource Management']
# ----------------------------------------------------------
# UDG Healthcare: Feedback from the management presentation  0.08058100936644771
# "Human Resource Management"  0.4506726246227427
# European Energy: UPDATE: European gas - a question of timing  0.041942675122125
# "Human Resource Management"  1.0000000000000002
#
# Recommending powerkri, 10 words similar to ['utility conference']
# ----------------------------------------------------------
# conference john strand  0.1514433188734461
# LNG Energy conference  0.12437674486577
# conference john strand  0.14692869979662454
# LNG Energy conference  0.16706648729767357
# LNG Energy conference  0.1228919885719515
# LNG Energy conference  0.17366849270591392
# LNG Energy conference  0.16597980889248765
#
# Recommending tlee3, 10 words similar to ['IG OTR 10 YR']
# ----------------------------------------------------------
# IG Credit  0.18465736558861473
# 5/18/18 Thermo Fisher : Analyst Day Preview  0.08484298158151139
# Euro Agg ex Corp 1-10 Yrs Aa  0.049516583636948656
#
# Recommending g01154429, 10 words similar to ['klarna']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending redsivar, 10 words similar to ['Long TRYZAR: Locked and re-loaded', 'Long TRYZAR: Locked and re-loaded', 'Long TRYZAR: Locked and re-loaded', 'Long TRYZAR: Locked and re-loaded']
# ----------------------------------------------------------
# Long TRYZAR: Locked and re-loaded  0.9999999999999996
# vesuvius  0.049533030871760864
#
# Recommending procarlo, 10 words similar to ['nipa', 'brexit impact']
# ----------------------------------------------------------
# brexit fx gbpusd  0.5119888180316353
# brexit fx gbpusd  0.1845974433349324
# brexit fx gbpusd  0.18652857797425554
# brexit fx gbpusd  0.2813387170672381
#
# Recommending kohlinik3, 10 words similar to ['novamatic']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending anumulaa, 10 words similar to ['Montagn&Atilde;&copy;, Fabrice']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending tsuchity, 10 words similar to ['Singapore: MAS policy preview – Contrarian bec...', 'Singapore: MAS policy preview – Contrarian bec...', 'Singapore: MAS policy preview: Contrarian beco...', 'Singapore: MAS policy preview: Contrarian beco...', "Short SGD 'NEER-lite'", "Short SGD 'NEER-lite'"]
# ----------------------------------------------------------
# short cycle update  0.1113899636604109
# short spreads  0.14947494415312326
#
# Recommending baudchhe, 10 words similar to ['Daily Macro & Strategy Research Summary']
# ----------------------------------------------------------
# daily credit  0.14049847540053637
# mixt  0.23476142693984078
# Daily Macro & Strategy Research Summary (London Open)  0.17203716881385595
# Equity Strategy  0.13465216804163366
# Global Daily Macro  0.29407450063866336
# Daily Macro & Strategy Research Summary (London Open)  0.710430334043729
# Daily Macro & Strategy Research Summary (London Open)  0.19365256786970078
#
# Recommending bouwmada, 10 words similar to ['week ahead', 'nflx', 'nflx', 'nflx', 'citigroup']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending gahirjas, 10 words similar to ['vesuvius', 'vsvs.l']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending chingpet, 10 words similar to ['insurance']
# ----------------------------------------------------------
# supply update  0.3773751044948796
# supply update  0.6014714647181088
#
# Recommending harribay, 10 words similar to ['blayne curtis', 'blayne curtis']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending grifhele, 10 words similar to ['question time', 'oil & gas weekly', 'shale']
# ----------------------------------------------------------
# shale initiation  0.5372741880074929
# shale initiation  0.5858278964029677
#
# Recommending wonsunny, 10 words similar to ['nan', 'nan', 'active vs smart beta']
# ----------------------------------------------------------
# phenomena across assets: bonds vs. equities of HY-rated  0.054712175843816366
#
# Recommending irfany, 10 words similar to ['ROCHE']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending popperda, 10 words similar to ['IAC']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending jankowc1, 10 words similar to ['municipal']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending azevedcl, 10 words similar to ['Sonae']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending altenbuj, 10 words similar to ['short cycle update', 'short cycle update']
# ----------------------------------------------------------
# short spreads  0.20380892678794135
# vesuvius  0.0716737577409144
# euro high yield corporate update  0.0647846895988671
# supply update  0.1522280710944226
# us high yield corporate update  0.08319471241194386
# Singapore: MAS policy preview – Contrarian becomes consensus  0.1113899636604109
#
# Recommending robillim, 10 words similar to ['MUS', 'Nos']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending raineha2, 10 words similar to ['helpdesk']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending kellemat, 10 words similar to ['Daily Macro & Strategy Research Summary (Londo...', 'Daily Credit Research Summary (London Open)', 'Barclays European Morning Research Summary']
# ----------------------------------------------------------
# Daily Macro & Strategy Research Summary (London Open)  0.12222042330836505
# morning FX  0.24812525831911553
# morning FX  0.13952520095642315
# Daily Macro & Strategy Research Summary (London Open)  0.1407201968731902
# Daily Macro & Strategy Research Summary  0.17203716881385595
# iPhone  0.23933789383829915
# mixt  0.22608766024000557
#
# Recommending ganeravi, 10 words similar to ['connect group', 'connect']
# ----------------------------------------------------------
# connect group  0.5794968839956507
#
# Recommending limamand1, 10 words similar to ['bumrungrad', 'healthcare', 'hailand', 'thailand healthcare']
# ----------------------------------------------------------
# UDG Healthcare: Feedback from the management presentation  0.11976725776120623
# healthcare  0.5235305662961388
# bumrungrad  0.5235305662961388
#
# Recommending marconad, 10 words similar to ['Q19 preview']
# ----------------------------------------------------------
# european banks preview  0.17930233464044606
# Singapore: MAS policy preview – Contrarian becomes consensus  0.09635494291505105
# 5/18/18 Thermo Fisher : Analyst Day Preview  0.06999791388992076
# arsley Energy / Jagged Peak Energy: Merger Agreement Continues Trend of Permian Consolidation and Negative Investor Response  0.08451604556475462
#
# Recommending kabhish1, 10 words similar to ['republic services']
# ----------------------------------------------------------
# Conference Call: North America Financial Services – Conference Recap & 2H19 Outlook  0.06978159636541376
# European Medical Technology & Services: Perspectives from the Middle East  0.08959600369561035
# Dominican Republic  0.3212622305578782
# European Medical Technology & Services: Perspectives from the Middle East  0.08958859875164193
#
# Recommending heimjord, 10 words similar to ['problems and the solutions']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending maltzder, 10 words similar to ['meacham']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending thomasju5, 10 words similar to ['vifor']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending lewismax5, 10 words similar to ['kronos']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending klosovaa, 10 words similar to ['tencent', 'tencent', 'mediclinic', 'mediclinic', 'KHC']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending romcgove, 10 words similar to ['apergy', 'apergy', 'clgx', 'clgx', 'jll', 'jll']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending willmoch1, 10 words similar to ['EUSF1A ICPL Curncy']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending mentobar, 10 words similar to ['autos', 'esg']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending wilso546, 10 words similar to ['iboxx bond']
# ----------------------------------------------------------
# bond screening tool  0.1836511854358426
# singapore bond  0.2773619490466152
# covered bond primer  0.18810408567840892
# IG Credit  0.18059643622388777
#
# Recommending cmills, 10 words similar to ['senior citizens and housing', 'senior citizens and housing', 'senior citizens', 'senior citizens', 'senior living']
# ----------------------------------------------------------
# senior citizens and housing  0.278838052174307
# senior citizens and housing  0.1897980144175221
# senior  0.502008861856484
#
# Recommending huntzpat, 10 words similar to ['ANSALDO', 'ansald']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending botelhfi1, 10 words similar to ['bayer']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending msheldon, 10 words similar to ['charty']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending honwah, 10 words similar to ['QE', 'QE5', 'QE4']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending baiausti, 10 words similar to ['auction manual']
# ----------------------------------------------------------
# auction manual  0.9999999999999998
# auction  0.560173460893011
#
# Recommending bhadekak, 10 words similar to ['schwechat', 'schwechat']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending adayarou1, 10 words similar to ['euro high yield corporate update']
# ----------------------------------------------------------
# food places in Clinton  0.12238211379706576
# european high yield  0.29780813979514215
# yield forecast  0.13286062224042947
# food places in Clinton  0.12465366125669443
# food places in Clinton  0.12194252694324426
# us high yield corporate update  0.778711623859959
# phenomena across assets: bonds vs. equities of HY-rated  0.13525682367327463
#
# Recommending schaubch5, 10 words similar to ['n26']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending kaplasan, 10 words similar to ['745 cafe', '745 cafe', '745 dining']
# ----------------------------------------------------------
# 745 cafe  0.3009667413446396
#
# Recommending nusbaujo2, 10 words similar to ['tempur', 'fxi']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending colemape3, 10 words similar to ['european high yield', 'central bank', 'distressed']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending fitzgeto4, 10 words similar to ['negative rates', 'negative rates']
# ----------------------------------------------------------
# brexit fx gbpusd  0.2119756197342947
# arsley Energy / Jagged Peak Energy: Merger Agreement Continues Trend of Permian Consolidation and Negative Investor Response  0.048488539499497676
#
# Recommending awanrams, 10 words similar to ['mixt', 'mixt', 'pmt', 'ppd', 'mix telematics', 'research', 'research', 'mix telematics', 'mixt', 'mixt', 'mixt', 'mixt']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending kohlinik, 10 words similar to ['eagruy', 'lycra']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending poyyaras, 10 words similar to ['UDG Healthcare: Feedback from the management p...']
# ----------------------------------------------------------
# bumrungrad  0.2287684148196593
# "Human Resource Management"  0.08058100936644771
# European Energy: UPDATE: European gas - a question of timing  0.0243078382663484
# bumrungrad  0.11976725776120623
# healthcare  0.2287684148196593
# "Human Resource Management"  0.0805810093664477
#
# Recommending guyile, 10 words similar to ['ashish', 'em weekly']
# ----------------------------------------------------------
# barclays global economics weekly  0.14298717152358223
# weekly recap  0.2609811624164163
# Kai Chang  0.2669886657664659
# question time  0.18090450015073634
# usmca  0.19201751555508523
# em flows  0.30658116867447477
#
# Recommending rowlancl, 10 words similar to ['wmh']
# ----------------------------------------------------------
# Please search more words to get recommendedation
# Recommending cowlingh, 10 words similar to ['fabege']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending vanwout1, 10 words similar to ['tomtom']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending garradvi, 10 words similar to ['EEMEA Instant Insights - Turkey (EM Macro & So...']
# ----------------------------------------------------------
# ashish  0.09323950901539729
# Daily Macro & Strategy Research Summary  0.038852322364809844
# usd cds  0.10437852480319963
# supply update  0.08651739809871098
# Global Daily Macro  0.06256931823377457
# em flows  0.09077522029694683
# Daily Macro & Strategy Research Summary (London Open)  0.027601868356006493
#
# Recommending chooadri1, 10 words similar to ['repo', 'repo', 'repo', 'easing', 'quantitative easing', 'qe']
# ----------------------------------------------------------
# ecb qe  0.5623176048323902
#
# Recommending hoamy1, 10 words similar to ['synfiny', 'synfiny']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending cottinjo1, 10 words similar to ['Addressing the potential pitfalls of cds', 'NTCE', 'NTCF', 'credit default']
# ----------------------------------------------------------
# supply update  0.2208691705929248
# european credit alpha  0.15037679614031155
# IG Credit  0.2026249375100303
# shale initiation  0.1979981389574169
# daily credit  0.21619219990153862
# US credit alpha  0.2208691705929248
# STATISTICS  0.13705925050999454
#
# Recommending challawa, 10 words similar to ['pesticides', 'syngenta']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending burckhaa, 10 words similar to ['dr copper']
# ----------------------------------------------------------
# bank  0.28866355309911085
# bank  0.5372741880074929
#
# Recommending zhutom, 10 words similar to ['daily credit']
# ----------------------------------------------------------
# IG Credit  0.22124415525252236
# Addressing the potential pitfalls of cds  0.21619219990153862
# Daily Macro & Strategy Research Summary (London Open)  0.3383217808975576
# supply update  0.24116485201500898
# US credit alpha  0.24116485201500898
# shale initiation  0.21619219990153862
# Global Daily Macro  0.22626430760439137
#
# Recommending devanned, 10 words similar to ['European Energy: UPDATE: European gas - a ques...', 'European Energy: Value in a lower-carbon world', 'European Energy: Value in a lower-carbon world', 'Global Consumer Health: Consumer Health Survey...', 'Global Consumer Staples: 300+ questions for ma...', 'European Food Producers: Disrupting the disrup...', 'European Food Producers: Disrupting the disrup...', 'Global Consumer Health: Update: Global Consume...', 'Global Consumer Health: Update: Global Consume...', 'IT Hardware and Communications Equipment: A Ro...']
# ----------------------------------------------------------
# wind equipment  0.10337369974086498
#
# Recommending lindehof, 10 words similar to ['aroundtown']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending miltonca, 10 words similar to ['elior']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending gunalanm, 10 words similar to ['Berlin', 'German Residential']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending baikcrys, 10 words similar to ['Itw']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending catalana, 10 words similar to ['initiate', 'airbus']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending brorsonl, 10 words similar to ['vesuvius', 'iNDUSTRIAL RECESSION CONTAGION – RISK SHIFTING...']
# ----------------------------------------------------------
# short cycle update  0.0716737577409144
# 5/18/18 Thermo Fisher : Analyst Day Preview  0.037863469225484746
# Long TRYZAR: Locked and re-loaded  0.049533030871760864
#
# Recommending richarph3, 10 words similar to ['trainline']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending teerapap, 10 words similar to ['korea']
# ----------------------------------------------------------
# Korea Focus  0.5483655543548437
#
# Recommending drurypau, 10 words similar to ['altice']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending grewalku, 10 words similar to ['U.S. Independent Refiners']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending zhoyingk, 10 words similar to ['wilson ho', 'chang jian', 'rotter, Rupert', 'rotter, Rupert']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending depinhan, 10 words similar to ['targa', 'gazprom']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending branshyu, 10 words similar to ['healthcare']
# ----------------------------------------------------------
# UDG Healthcare: Feedback from the management presentation  0.2287684148196593
# bumrungrad  0.5235305662961388
#
# Recommending artetae2, 10 words similar to ['sofr']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending vargfran, 10 words similar to ['Ecuador', 'Ecuador']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending chenchin, 10 words similar to ['Fed watch', 'Fed']
# ----------------------------------------------------------
# Fed watch  0.5372741880074929
#
# Recommending misraric, 10 words similar to ['convexity', 'convexity']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending likevin7, 10 words similar to ['linkem']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending leibovje, 10 words similar to ['Ruussia', 'quasi']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending martnmig, 10 words similar to ['Global Daily Macro']
# ----------------------------------------------------------
# global economy  0.1476761602131474
# ludovico sapio  0.162429722275541
# Global Outlook  0.162429722275541
# Daily Macro & Strategy Research Summary (London Open)  0.20891944572246837
# Daily Macro & Strategy Research Summary  0.29407450063866336
# supply update  0.20840029460314058
# daily credit  0.22626430760439137
#
# Recommending kuoangel, 10 words similar to ['Construction']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending holtsusa, 10 words similar to ['brexit fx gbpusd', 'brexit fx', 'brexit', 'brexit exchange rates']
# ----------------------------------------------------------
# brexit fx gbpusd  0.1313560587214662
# nipa  0.1845974433349324
# negative rates  0.2119756197342947
# brexit fx gbpusd  0.19812269755686793
# brexit fx gbpusd  0.36054975584159393
#
# Recommending huangjos5, 10 words similar to ['european banks', 'european banks']
# ----------------------------------------------------------
# supply update  0.20930375573212953
# lebanese banks  0.31329692588997554
# european high yield  0.14446617166033826
# european credit alpha  0.15077448250297829
# European Pharmaceuticals  0.20585480330169495
# european banks  1.0000000000000002
# european banks preview  0.6483764841206634
#
# Recommending dromerse, 10 words similar to ['us tariffs', 'tariffs']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending bonhomma1, 10 words similar to ['weekly recap']
# ----------------------------------------------------------
# Kai Chang  0.2599164294788735
# Conference Call: North America Financial Services – Conference Recap & 2H19 Outlook  0.08380447333236433
# ashish  0.2609811624164163
# barclays global economics weekly  0.1391995985185401
# question time  0.17611253878832447
# usmca  0.18693118262981476
#
# Recommending vanvlota, 10 words similar to ['santos']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending vincense, 10 words similar to ['singapore bond']
# ----------------------------------------------------------
# bond screening tool  0.19432096768648013
# Singapore: MAS policy preview – Contrarian becomes consensus  0.11550409221871058
# iboxx bond  0.2773619490466152
# covered bond primer  0.19903257290750462
# IG Credit  0.1910887433940105
#
# Recommending singjask4, 10 words similar to ['equate petrochemicals']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending atallahr, 10 words similar to ['Kai Chang', 'Oils weekly', 'Oils weekly']
# ----------------------------------------------------------
# Kai Chang  0.9999999999999998
# question time  0.18016645845425225
# barclays global economics weekly  0.1424038223279636
# ashish  0.2669886657664659
# weekly recap  0.2599164294788735
# usmca  0.19123413574520295
#
# Recommending larachdi, 10 words similar to ['minerva', 'bci', 'banco santander', 'banco de chile']
# ----------------------------------------------------------
# Chile Quarterly Outlook  0.2311814740625955
# minerva  0.3071798304174673
# "banco santander"  0.3071798304174673
#
# Recommending ohyiming, 10 words similar to ['bharti airtel']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending nestermi1, 10 words similar to ['global outlook uncertainty', 'time to play defence']
# ----------------------------------------------------------
# question time  0.21955628686103226
#
# Recommending kylecarr, 10 words similar to ['GOOGL', 'google']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending radebran, 10 words similar to ['envirotainer']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending e20041139, 10 words similar to ['UK', 'UK']
# ----------------------------------------------------------
# uk contractors  0.5076367347422112
# uk property  0.3386889183569871
# uk property  0.48529899464450255
# uk jobs report  0.33122335287494176
#
# Recommending chiuchri, 10 words similar to ['hope trade']
# ----------------------------------------------------------
# live nation entertainment  0.11816699885414825
# live nation entertainment  0.14338148243189378
# trade traiff  0.2717463022287522
# trade  0.5307660883561742
# rating suspended  0.2837895743463109
#
# Recommending ishizato1, 10 words similar to ['ladder']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending pintopat, 10 words similar to ['European Food Retail']
# ----------------------------------------------------------
# European Energy: UPDATE: European gas - a question of timing  0.25014779521265684
# pet food  0.2033316019756188
# european banks  0.14247899872853156
# food places in Clinton  0.13512957632659742
# asset managers  0.14247899872853156
# retail detail  0.4281327914327501
#
# Recommending sapiolud, 10 words similar to ['abbas khan']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending pdennehy, 10 words similar to ['SERIES-E']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending carusale, 10 words similar to ['auction']
# ----------------------------------------------------------
# auction manual  0.560173460893011
#
# Recommending sampedpa, 10 words similar to ['spanish bondco']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending moorecol, 10 words similar to ['airbus', 'airbus']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending chowdsre, 10 words similar to ['blue drum']
# ----------------------------------------------------------
# ...
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending lijennif2, 10 words similar to ['global economy', 'global economy']
# ----------------------------------------------------------
# Global Outlook  0.23477824430546562
# global outlook uncertainty  0.14536804911334614
# global traders guide  0.1383786642489344
# Global Daily Macro  0.1476761602131474
# usmca  0.1383786642489344
# ludovico sapio  0.23477824430546562
# usmca  0.14830857749261528
#
# Recommending kafemich, 10 words similar to ['eskom']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending petrishe, 10 words similar to ['volatility']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending levihaay, 10 words similar to ['CIMS']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending morrryan, 10 words similar to ['alternative meat', 'alternative meat']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending baterob, 10 words similar to ['chang jian']
# ----------------------------------------------------------
# chang jian  0.9999999999999998
# Kai Chang  0.3009667413446396
#
# Recommending koikemic, 10 words similar to ['verso', 'verso']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending phill224, 10 words similar to ['uk property', 'uk house market']
# ----------------------------------------------------------
# uk contractors  0.1719309366081123
# UK  0.3386889183569871
# uk property  0.16436539157587984
# usmca  0.14373533238101122
# primer  0.19629851981317098
#
# Recommending holsteh1, 10 words similar to ['elanco']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending demarta, 10 words similar to ['supply']
# ----------------------------------------------------------
# supply update  0.5794671411210202
# supply update  0.5235305662961388
# treasury supply  0.5534110325007742
#
# Recommending wongjack5, 10 words similar to ['tartaruga', 'etroliam Nasional Berhad', 'etronas']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending radhakar1, 10 words similar to ['gold forecast']
# ----------------------------------------------------------
# US Treasury Forecast  0.24870492570525726
# US Treasury Forecast  0.25939889759783047
# US Treasury Forecast  0.17354345729883613
# interest rate forecast  0.25939889759783047
# yield forecast  0.24255019002323383
#
# Recommending mauryada, 10 words similar to ['iPhone', 'barclays']
# ----------------------------------------------------------
# barclays global economics weekly  0.2993077018972554
# Daily Macro & Strategy Research Summary (London Open)  0.23933789383829915
# 5/18/18 Thermo Fisher : Analyst Day Preview  0.19411497206927775
#
# Recommending zhouxand, 10 words similar to ['repo primer', 'joseph abate']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending wangshul, 10 words similar to ['qiagen', 'tecan group ag', 'tecan group ag', 'Sysmex', '6869-JP', 'SHL', 'Satorius', 'SRT', 'RGEN', 'RGEN', 'repligen', 'RGEN', 'RGEN', 'KI', 'DIA-IT', 'Diasorin', 'bio-techne', 'biomerieux', 'bim-fr', 'bim-fr', 'abcam plc', 'agilent', 'ABCAM', 'ABCAM', 'ABCAM', 'ABCM', 'A', 'ABC-GB']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending arslangu1, 10 words similar to ['epfr']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending zewinsma, 10 words similar to ['point', 'point']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending rtishcek, 10 words similar to ['creal']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending balasrag, 10 words similar to ['sandler']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending kmurphy2, 10 words similar to ['gvc', 'gvc', 'milene', 'milene', 'airbus', 'airbus', 'airb', 'airb']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending cartlecl, 10 words similar to ['tank trailer', 'engines', 'trucks and engines', 'trucks and engines']
# ----------------------------------------------------------
# tank trailer  0.560173460893011
# tank trailer  0.9999999999999998
#
# Recommending kwitteck, 10 words similar to ['asml']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending dempseni, 10 words similar to ['threatmetrix', 'mack brooks', 'threatmetrix', "Assassin's Creed Odyssey"]
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending makrita, 10 words similar to ['tio2']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending bocciava, 10 words similar to ['prosus', 'prosus']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending yankimbe, 10 words similar to ['"GLOBAL 2019 e&P sPENDING oUTLOOK"', '"GLOBAL 2018 e&P sPENDING oUTLOOK"', 'e&P sPENDING', 'nam spending survey', 'nam spending survey']
# ----------------------------------------------------------
# European Energy: UPDATE: European gas - a question of timing  0.04498792692959658
# supply update  0.21473996229373407
# "GLOBAL 2019 e&P sPENDING oUTLOOK"  0.37638943530735025
# "GLOBAL 2019 e&P sPENDING oUTLOOK"  1.0000000000000002
# "GLOBAL 2019 e&P sPENDING oUTLOOK"  0.11016209513850637
# "GLOBAL 2019 e&P sPENDING oUTLOOK"  0.10857313455683845
#
# Recommending forresal1, 10 words similar to ['clo']
# ----------------------------------------------------------
# CLO myth busters  0.34462015518214745
#
# Recommending chojessi, 10 words similar to ['ESLA', 'MSFT', 'General Motors', 'FANG', 'NIKE', 'AMZN', 'AMZN']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending choutony, 10 words similar to ['WD']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending rashidma1, 10 words similar to ['snbr']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending bajakch, 10 words similar to ['food places in Clinton', 'US Investment Grade Corporate', 'US Investment Grade Corporate Update June 2019', 'US Investment Grade Corporate Update September...', 'US Investment Grade Corporate Update September...', 'US Investment Grade Corporate Update September...', 'US Investment Grade Corporate Update September...', 'US Investment Grade Corporate Update September...']
# ----------------------------------------------------------
# food places in Clinton  0.38185796632033503
# us high yield corporate update  0.15715973673339512
# food places in Clinton  0.4889674039018749
# food places in Clinton  0.6200701446349947
# food places in Clinton  0.6338560935406488
# investment grade credit metrics  0.16209492007265594
#
# Recommending agrawata, 10 words similar to ['C STAKE']
# ----------------------------------------------------------
# NMC Health PLC: A clean beat in H1, new buyback & reports of bidders for NMC stake  0.10615284511416852
#
# Recommending mealoral, 10 words similar to ['korea']
# ----------------------------------------------------------
# Korea Focus  0.5483655543548437
#
# Recommending widenann, 10 words similar to ['morning FX', 'morning']
# ----------------------------------------------------------
# morning FX  0.5623176048323902
# Daily Macro & Strategy Research Summary (London Open)  0.24812525831911553
#
# Recommending siberjos2, 10 words similar to ['grub']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending moowilli, 10 words similar to ['rahul bajoria', 'rahul bajoria']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending nichofra, 10 words similar to ['datadog', 'data dog']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending rosquisd, 10 words similar to ['postcard from schw', 'postcard from schw']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending leelawre9, 10 words similar to ['mas']
# ----------------------------------------------------------
# Singapore: MAS policy preview – Contrarian becomes consensus  0.213211667484121
#
# Recommending nuttallg, 10 words similar to ['MOYEEN ISLAM']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending hoogenj4, 10 words similar to ['asset managers', 'European Banks']
# ----------------------------------------------------------
# supply update  0.20930375573212953
# lebanese banks  0.31329692588997554
# european high yield  0.14446617166033826
# european credit alpha  0.15077448250297829
# European Pharmaceuticals  0.20585480330169495
# european banks  1.0000000000000002
# european banks preview  0.6483764841206634
#
# Recommending chisherm, 10 words similar to ['asia week ahead', 'asia week ahead']
# ----------------------------------------------------------
# thoughts for the week ahead  0.4283227217474008
# houghts for the Week Ahead: Breaking the impasse, maybe  0.1934935253872392
# week ahead  0.6377370911117642
# European Energy: UPDATE: European gas - a question of timing  0.038341047111778936
# asia week ahead  1.0000000000000004
#
# Recommending schwar13, 10 words similar to ['fast', 'fastenal']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending wukathy, 10 words similar to ['dcp']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending mirzanib, 10 words similar to ['eoangr', 'eoangr', 'eon', 'eon']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending polonfra, 10 words similar to ['jussi']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending debernel, 10 words similar to ['getlink']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending shibaasa, 10 words similar to ['tiering', 'tiering']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending gadeypre, 10 words similar to ['Bloom brc', 'Bloom brc']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending balsaren, 10 words similar to ['huarong']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending lineric2, 10 words similar to ['Blackberry', 'Blackberry reset password', 'Blackberry reset password']
# ----------------------------------------------------------
# Blackberry  0.393231670302591
#
# Recommending cremerjo2, 10 words similar to ['investment grade credit metrics']
# ----------------------------------------------------------
# food places in Clinton  0.16209492007265594
# supply update  0.12075985557454555
# food places in Clinton  0.33150455179459126
# food places in Clinton  0.16510358116279134
# food places in Clinton  0.16151268796598273
# food places in Clinton  0.15601053120490582
#
# Recommending saitabdu, 10 words similar to ['US credit alpha']
# ----------------------------------------------------------
# US credit alpha  1.0000000000000002
# IG Credit  0.2260304168763358
# Addressing the potential pitfalls of cds  0.2208691705929248
# STATISTICS  0.15289114908671428
# daily credit  0.24116485201500898
# european credit alpha  0.6808410414935867
# supply update  1.0000000000000002
# shale initiation  0.2208691705929248
#
# Recommending ardurag, 10 words similar to ['prosus', 'prosus']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending howellge1, 10 words similar to ['european credit alpha']
# ----------------------------------------------------------
# european banks  0.15077448250297829
# US credit alpha  0.6808410414935867
# IG Credit  0.15389078443531398
# daily credit  0.16419492901754537
# supply update  0.6808410414935867
# European Credit Overview: Sound of silence  0.23461185484504576
# asset managers  0.15077448250297829
#
# Recommending liuzack, 10 words similar to ['gdp forecasts']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending burnetj, 10 words similar to ['usd cds', 'turkey cds']
# ----------------------------------------------------------
# Addressing the potential pitfalls of cds  0.14959595330057499
# EEMEA Instant Insights - Turkey (EM Macro & Sovereigns)  0.10437852480319963
# usd cds  0.29583515093548346
# cds index positioning  0.19363681160288157
#
# Recommending jethwana, 10 words similar to ['smile direct']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending robinsan1, 10 words similar to ['CLO']
# ----------------------------------------------------------
# CLO myth busters  0.34462015518214745
#
# Recommending licharl4, 10 words similar to ['CLO', 'CLO']
# ----------------------------------------------------------
# CLO myth busters  0.34462015518214745
#
# Recommending haefligd, 10 words similar to ['tesla']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending verniemi1, 10 words similar to ['trade']
# ----------------------------------------------------------
# rating suspended  0.5346791751998141
# trade traiff  0.5119888180316353
# hope trade  0.5307660883561742
#
# Recommending claracch2, 10 words similar to ['CLO']
# ----------------------------------------------------------
# CLO myth busters  0.34462015518214745
#
# Recommending e01933244, 10 words similar to ['crossover']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending derdeyma1, 10 words similar to ['live nation entertainment', 'European/US Gaming: Land of Hope & Opportunity...', 'European/US Gaming: Land of Hope & Opportunity', 'sports betting']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending walterhe1, 10 words similar to ['Equity Strategy', 'factor']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending patterly1, 10 words similar to ['fallen angel reversal', 'fallen angel resversal']
# ----------------------------------------------------------
# fallen angel reversal  0.4701744627064415
#
# Recommending saxenaab1, 10 words similar to ['short spreads', 'spreads']
# ----------------------------------------------------------
# short spreads  0.5844529394015618
#
# Recommending newnhast1, 10 words similar to ['ulvr']
# ----------------------------------------------------------
# Please search more words to get recommendedation
#
# Recommending calvinw, 10 words similar to ['cds index positioning']
# ----------------------------------------------------------
# usd cds  0.19363681160288157
# Addressing the potential pitfalls of cds  0.10136869220226338
# usd cds  0.20046279124633173
